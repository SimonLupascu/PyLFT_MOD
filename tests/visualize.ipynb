# %%
import py3Dmol
import os
import glob

notebook_dir = os.path.dirname(os.path.abspath('__file__'))
xyz_files = sorted(glob.glob(os.path.join(notebook_dir, '*.xyz')))

if not xyz_files:
    print('No .xyz files found. Run test_architector.py first.')
else:
    print('Available complexes:')
    for i, f in enumerate(xyz_files):
        print(f'  [{i}] {os.path.basename(f)}')

    # Change this number to switch between molecules
    selected = 0

    xyz_path = xyz_files[selected]
    print(f'Showing: {os.path.basename(xyz_path)}')

    with open(xyz_path) as f:
        xyz_data = f.read()

#See py3Dmol bibliography --- may need fixing /// SOS!
    viewer = py3Dmol.view(width=700, height=500)
    viewer.addModel(xyz_data, 'xyz')
    viewer.setStyle({'sphere': {'scale': 0.3}, 'stick': {'radius': 0.15}})

    axis_length = 4.0
    axis_radius = 0.05

    # X axis — red
    viewer.addCylinder({'start': {'x': -axis_length, 'y': 0, 'z': 0},
                        'end':   {'x':  axis_length, 'y': 0, 'z': 0},
                        'radius': axis_radius, 'color': 'red', 'opacity': 0.8})
    viewer.addLabel('X', {'position': {'x': axis_length + 0.3, 'y': 0, 'z': 0},
                          'fontColor': 'red', 'fontSize': 14, 'backgroundColor': 'transparent'})

    # Y axis — green
    viewer.addCylinder({'start': {'x': 0, 'y': -axis_length, 'z': 0},
                        'end':   {'x': 0, 'y':  axis_length, 'z': 0},
                        'radius': axis_radius, 'color': 'green', 'opacity': 0.8})
    viewer.addLabel('Y', {'position': {'x': 0, 'y': axis_length + 0.3, 'z': 0},
                          'fontColor': 'green', 'fontSize': 14, 'backgroundColor': 'transparent'})

    # Z axis — blue
    viewer.addCylinder({'start': {'x': 0, 'y': 0, 'z': -axis_length},
                        'end':   {'x': 0, 'y': 0, 'z':  axis_length},
                        'radius': axis_radius, 'color': 'blue', 'opacity': 0.8})
    viewer.addLabel('Z', {'position': {'x': 0, 'y': 0, 'z': axis_length + 0.3},
                          'fontColor': 'blue', 'fontSize': 14, 'backgroundColor': 'transparent'})

    viewer.zoomTo()
    viewer.show()

    #Possible addition: Make an interface instead of providing the molecule inside the Jupyter Notebook?
# Out:
# Available complexes:
#   [0] Fe_OH2_oct.xyz
#   [1] octahedral_complex.xyz
# Showing: Fe_OH2_oct.xyz
# <div id="3dmolviewer_17785034187259269"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_17785034187259269" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17785034187259269 = null;
# var warn = document.getElementById("3dmolwarning_17785034187259269");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17785034187259269 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17785034187259269"),{backgroundColor:"white"});
# viewer_17785034187259269.zoomTo();
# 	viewer_17785034187259269.addModel("19\nHomoleptic Octahedral Complex - Generated by Architector\nFe  0.000000  0.000000  0.000000\nO  0.003000  0.006400  2.353400\nH  0.499000  -0.586100  2.927900\nH  -0.499700  0.577100  2.943500\nO  0.011400  -0.003500  -2.355300\nH  0.049500  -0.766300  -2.941200\nH  -0.063300  0.761700  -2.934800\nO  2.344300  -0.016400  0.005500\nH  2.926900  0.191400  0.744100\nH  2.921300  -0.173900  -0.749500\nO  -2.345000  0.002600  0.003100\nH  -2.934200  0.191500  0.740900\nH  -2.917900  -0.197600  -0.745000\nO  -0.014100  2.345900  0.001700\nH  0.056500  2.933200  -0.758000\nH  -0.040000  2.927000  0.768900\nO  0.003800  -2.345100  -0.002900\nH  0.214900  -2.941100  -0.728800\nH  -0.218200  -2.916300  0.739900\n","xyz");
# 	viewer_17785034187259269.setStyle({"sphere": {"scale": 0.3}, "stick": {"radius": 0.15}});
# 	viewer_17785034187259269.addCylinder({"start": {"x": -4.0, "y": 0, "z": 0}, "end": {"x": 4.0, "y": 0, "z": 0}, "radius": 0.05, "color": "red", "opacity": 0.8});
# 	viewer_17785034187259269.addLabel("X",{"position": {"x": 4.3, "y": 0, "z": 0}, "fontColor": "red", "fontSize": 14, "backgroundColor": "transparent"});
# 	viewer_17785034187259269.addCylinder({"start": {"x": 0, "y": -4.0, "z": 0}, "end": {"x": 0, "y": 4.0, "z": 0}, "radius": 0.05, "color": "green", "opacity": 0.8});
# 	viewer_17785034187259269.addLabel("Y",{"position": {"x": 0, "y": 4.3, "z": 0}, "fontColor": "green", "fontSize": 14, "backgroundColor": "transparent"});
# 	viewer_17785034187259269.addCylinder({"start": {"x": 0, "y": 0, "z": -4.0}, "end": {"x": 0, "y": 0, "z": 4.0}, "radius": 0.05, "color": "blue", "opacity": 0.8});
# 	viewer_17785034187259269.addLabel("Z",{"position": {"x": 0, "y": 0, "z": 4.3}, "fontColor": "blue", "fontSize": 14, "backgroundColor": "transparent"});
# 	viewer_17785034187259269.zoomTo();
# viewer_17785034187259269.render();
# });
# </script>
